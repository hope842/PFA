# %% [markdown]
# <a href="https://colab.research.google.com/github/hope842/PFA/blob/main/pfa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/FutureComputing4AI/EMBER2024.git
# Out:
# Cloning into 'EMBER2024'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 69 (delta 22), reused 52 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 42.06 KiB | 1.05 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
# %cd /content/EMBER2024/
# %pwd
# !pip install .
# Out:
# /content/EMBER2024
# Processing /content/EMBER2024
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 91.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.6/194.6 kB 20.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 621.5/621.5 kB 52.6 MB/s eta 0:00:00
# ...
#   Created wheel for thrember: filename=thrember-0.1.0-py3-none-any.whl size=26781 sha256=46806c4dfec399b96ecafb64a9e4a9469cfac7ef95ab8375e487178867456f11
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yj8bn4b8/wheels/21/ee/ca/911b4783aa75e217485919f249cb705350c3244fd7894fbb21
# Successfully built thrember
# ...

# %%
import thrember


# !mkdir -p /content/EMBER_dataset
# !mkdir -p /content/EMBER_models
thrember.download_models("/content/EMBER_models")

thrember.download_dataset("/content/EMBER_dataset", file_type="Dot_Net", split="train")
thrember.download_dataset("/content/EMBER_dataset", file_type="Dot_Net", split="test")

thrember.download_dataset("/content/EMBER_dataset", split="challenge")
# Out:
# Dot_Net_train.zip:   0%|          | 0.00/937M [00:00<?, ?B/s]
# Unzipping...
# Dot_Net_test.zip:   0%|          | 0.00/220M [00:00<?, ?B/s]
# Unzipping...
# challenge.zip:   0%|          | 0.00/32.1M [00:00<?, ?B/s]

# %%
# %pwd
# Out:
# '/content/EMBER_dataset'
